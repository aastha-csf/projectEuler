# %% [markdown]
# #### Problem Zero – Problem 0
#
# ##### Question
# A number is a perfect square, or a square number, if it is the square of a positive integer.
# For example, 25 is a square number because $5^2 = 5 \times 5 = 25$   ; it is also an odd square.
#
# Among the first 476 thousand square numbers, what is the sum of all the odd squares?
#
#
# ##### Logic (Brute Force)
# 1. Iterate through all numbers from `1` to `n`
# 2. For each number `i`, compute $i^2$
# 3. If $i^2$ is odd, add it to `sumOfOddSquares`
#
# This approach directly follows the problem definition but performs unnecessary computations.
#
# ##### Optimized Approach
# - A square is **odd if and only if** the base number is odd.
# - Therefore, instead of checking every number from `1` to `n`, we can:
#   - Iterate only over **odd numbers**
#   - Square each odd number
#   - Add the result to the sum
#
# This avoids redundant checks and simplifies the condition.
#
# ##### Time & Space Complexity
# - **Time:** \(O(n)\)
# - **Space:** \(O(1)\)

# %%
n = 803000
sumOfOddSquares = 0
for i in range(1, n+1, 2):
    sumOfOddSquares += (i*i)
print(sumOfOddSquares)
# Out:
# 86296937833199500
